# %%
import pandas as pd
import os 
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline
plt.rcParams['figure.figsize']=10,5
import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir('E:\\Data Visulalilzation\\rajanand-crime-in-india')
murders = pd.read_csv('32_Murder_victim_age_sex.csv')
murders
# Out:
#                       Area_Name  Year               Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Murder - Female Victims
# 1                Andhra Pradesh  2001  Murder - Female Victims
# 2             Arunachal Pradesh  2001  Murder - Female Victims
# 3                         Assam  2001  Murder - Female Victims
# 4                         Bihar  2001  Murder - Female Victims
# 5                    Chandigarh  2001  Murder - Female Victims
# 6                  Chhattisgarh  2001  Murder - Female Victims
# 7                         Delhi  2001  Murder - Female Victims
# 8                           Goa  2001  Murder - Female Victims
# 9                       Gujarat  2001  Murder - Female Victims
# 10                      Haryana  2001  Murder - Female Victims
# 11             Himachal Pradesh  2001  Murder - Female Victims
# 12              Jammu & Kashmir  2001  Murder - Female Victims
# 13                    Jharkhand  2001  Murder - Female Victims
# ...

# %%
murders.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Victims_Above_50_Yrs', 'Victims_Total', 'Victims_Upto_10_15_Yrs',
#        'Victims_Upto_10_Yrs', 'Victims_Upto_15_18_Yrs',
#        'Victims_Upto_18_30_Yrs', 'Victims_Upto_30_50_Yrs'],
#       dtype='object')

# %% [markdown]
# ----

# %% [markdown]
# ---

# %% [markdown]
# Q-2 •	Offenders relation with rape victim

# %%
offenders = pd.read_csv('21_Offenders_known_to_the_victim.csv')

# %%
offenders.columns
# Out:
# Index(['Area_Name', 'Year',
#        'No_of_Cases_in_which_offenders_were_known_to_the_Victims',
#        'No_of_Cases_in_which_offenders_were_Neighbours',
#        'No_of_Cases_in_which_offenders_were_Other_Known_persons',
#        'No_of_Cases_in_which_offenders_were_Parentsclose_family_members',
#        'No_of_Cases_in_which_offenders_were_Relatives'],
#       dtype='object')

# %%
offenders.columns=['Area', 'Year','k_t_Victims','Neighbours','Known_persons','Parentsclose','Relatives']

# %%
off = offenders[['Area','k_t_Victims','Neighbours','Known_persons','Parentsclose','Relatives']]

# %%
off=off.groupby('Area').sum()
off
# Out:
#                            k_t_Victims  Neighbours  Known_persons  \
# Area
# Andaman & Nicobar Islands           84          13             69
# Andhra Pradesh                   10601        3788           5853
# Arunachal Pradesh                  412          46            360
# Assam                            12632        4066           7694
# Bihar                            11234        5100           6034
# Chandigarh                         226          63            133
# Chhattisgarh                      9735        2884           5463
# Dadra & Nagar Haveli                48          17             31
# Daman & Diu                         14           6              8
# Delhi                             4825        2600           1693
# Goa                                248          87            143
# Gujarat                           3229         634           2334
# Haryana                           4818        1983           2444
# ...

# %%
sns.set_style('darkgrid')
z = sns.boxplot(data=off,)
